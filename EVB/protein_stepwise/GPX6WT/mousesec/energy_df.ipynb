# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import table

# Example input data as a list of lists
data = [
    ['Replica0',  '16.35' , '-40.8'],
    ['Replica1',  '26.15', '-10.68'],
    ['Replica2', '9.27', '-47.32'],
    ['Replica3', '9.18', '-48.26'],
    ['Replica4', '11.71', '-43.79'],
    ['Replica5', '11.81', '-44.54'],
    ['Replica6', '10.78', '-44.10'],
    ['Replica7', '7.04', '-53.21'],
    ['Replica8', '21.12', '-35.27'],
    ['Replica9', '18.1', '-25.74'],    # hij - 25 , alpha - 50
    ['Merged Replica', '52.86', '-65.67']
]

# Specify column names
columns = ['Mouse Sec', 'dG* Mean', 'dG0 Mean']

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

# Print the DataFrame
print(df)

# Plotting the table
fig, ax = plt.subplots(figsize=(15, 3))  # Adjust size as needed
ax.axis('tight')
ax.axis('off')

# Add a table at the bottom of the axes
table_plot = table(ax, df, loc='center', cellLoc='center', colWidths=[0.2]*len(df.columns))

# Format the table
table_plot.auto_set_font_size(False)
table_plot.set_fontsize(12)
table_plot.scale(1.2, 1.2)

ax.set_title('Step 1 of Reaction 1')  # Set the title using ax.set_title method
plt.show()  # Display the table
# Out:
#          Mouse Sec dG* Mean dG0 Mean
# 0         Replica0    16.35    -40.8
# 1         Replica1    26.15   -10.68
# 2         Replica2     9.27   -47.32
# 3         Replica3     9.18   -48.26
# 4         Replica4    11.71   -43.79
# 5         Replica5    11.81   -44.54
# 6         Replica6    10.78   -44.10
# 7         Replica7     7.04   -53.21
# 8         Replica8    21.12   -35.27
# 9         Replica9     18.1   -25.74
# 10  Merged Replica    52.86   -65.67

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import table

# Example input data as a list of lists
data = [
    ['Replica0',  '18.87' , '-4.54'],
    ['Replica1',  '20.31', '6.91'],
    ['Replica2', '32.19', '1.62'],
    ['Replica3', '23.63', '-5'],
    ['Replica4', '25.46', '-1.42'],
    ['Replica5', '44.48', '19.97'],
    ['Replica6', '44.01', '7.22'],
    ['Replica7', '43.35', '8.43'],
    ['Replica8', '50.36', '36.34'],
    ['Replica9', '32.43', '14.97']
]

# Specify column names
columns = ['Mouse Sec', 'dG* Mean', 'dG0 Mean']

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

# Print the DataFrame
print(df)

# Plotting the table
fig, ax = plt.subplots(figsize=(15, 3))  # Adjust size as needed
ax.axis('tight')
ax.axis('off')

# Add a table at the bottom of the axes
table_plot = table(ax, df, loc='center', cellLoc='center', colWidths=[0.2]*len(df.columns))

# Format the table
table_plot.auto_set_font_size(False)
table_plot.set_fontsize(12)
table_plot.scale(1.2, 1.2)

ax.set_title('Step 2 of Reaction 1')  # Set the title using ax.set_title method
plt.show()  # Display the table
# Out:
#   Mouse Sec dG* Mean dG0 Mean
# 0  Replica0    18.87    -4.54
# 1  Replica1    20.31     6.91
# 2  Replica2    32.19     1.62
# 3  Replica3    23.63       -5
# 4  Replica4    25.46    -1.42
# 5  Replica5    44.48    19.97
# 6  Replica6    44.01     7.22
# 7  Replica7    43.35     8.43
# 8  Replica8    50.36    36.34
# 9  Replica9    32.43    14.97
