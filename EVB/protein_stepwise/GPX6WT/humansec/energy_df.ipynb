# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import table

# Example input data as a list of lists
data = [
    ['Replica0',  '11.56' , '-36.35'],
    ['Replica1',  '15.31', '-26.29'],
    ['Replica2', '17.15', '-32.66'],
    ['Replica3', '19.77', '-26.34'],
    ['Replica4', '16.14', '-26.18'],
    ['Replica5', '17.98', '-27.27'],
    ['Replica6', '5.19', '-38.64'],
    ['Replica7', '16.24', '-26.68'],
    ['Replica8', '0.59', '-42.71'],
    ['Replica9', '18.35', '-20.8'],
    ['Merged Replica', 35, 'Chicago']
]

# Specify column names
columns = ['Human Sec', 'dG* Mean', 'dG0 Mean']

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

# Print the DataFrame
print(df)

# Plotting the table
fig, ax = plt.subplots(figsize=(15, 3))  # Adjust size as needed
ax.axis('tight')
ax.axis('off')

# Add a table at the bottom of the axes
table_plot = table(ax, df, loc='center', cellLoc='center', colWidths=[0.2]*len(df.columns))

# Format the table
table_plot.auto_set_font_size(False)
table_plot.set_fontsize(12)
table_plot.scale(1.2, 1.2)

ax.set_title('Step 1 of Reaction 1')  # Set the title using ax.set_title method
plt.show()  # Display the table

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import table

# Example input data as a list of lists
data = [
    ['Replica0',  '45.13' , '10.09'],
    ['Replica1',  '30.83' , '4.09'],
    ['Replica2', '37.03', '14.7'],
    ['Replica3', '38.5', '-1.14'],
    ['Replica4', '47.29', '6.19'],
    ['Replica5', '27.46', '6.30'],
    ['Replica6', '36.25', '-1.24'],
    ['Replica7', '27.85', '-3.31'],
    ['Replica8', '32.86', '4.9'],
    ['Replica9', '34.83', '26.71'],
    ['Merged Replica', 35, 'Chicago']
]

# Specify column names
columns = ['Human Sec', 'dG* Mean', 'dG0 Mean']

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

# Print the DataFrame
print(df)

# Plotting the table
fig, ax = plt.subplots(figsize=(15, 3))  # Adjust size as needed
ax.axis('tight')
ax.axis('off')

# Add a table at the bottom of the axes
table_plot = table(ax, df, loc='center', cellLoc='center', colWidths=[0.2]*len(df.columns))

# Format the table
table_plot.auto_set_font_size(False)
table_plot.set_fontsize(12)
table_plot.scale(1.2, 1.2)

ax.set_title('Step 2 of Reaction 1')  # Set the title using ax.set_title method
plt.show()  # Display the table
# Out:
#          Human Sec dG* Mean dG0 Mean
# 0         Replica0    45.13    10.09
# 1         Replica1    30.83     4.09
# 2         Replica2    37.03     14.7
# 3         Replica3     38.5    -1.14
# 4         Replica4    47.29     6.19
# 5         Replica5    27.46     6.30
# 6         Replica6    36.25    -1.24
# 7         Replica7    27.85    -3.31
# 8         Replica8    32.86      4.9
# 9         Replica9    34.83    26.71
# 10  Merged Replica       35  Chicago
