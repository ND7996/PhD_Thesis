               3.718, 3.693, 3.687, 3.669, 3.693, 3.707, 3.700, 3.532, 3.418, 3.354, 
               3.352, 3.361, 3.349, 3.353, 3.368, 3.376, 3.386, 3.402, 3.442, 3.471, 
               3.523, 3.555, 3.510, 3.368, 3.389, 3.543, 3.727, 3.979, 4.061, 4.057, 
               3.942, 3.923, 3.681, 3.157, 2.400, 2.297, 2.140, 2.416, 2.488, 2.373]
}

df = pd.DataFrame(data)

# Step 2: Create the violin plot
plt.figure(figsize=(12, 8))
sns.violinplot(data=df, y="<dGg>")
plt.title('Violin Plot of <dGg>')
plt.xlabel('Data Points')
plt.ylabel('<dGg>')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Create the DataFrame with the first 25 rows
data = {
    "bin": range(1, 26),
    "energy_gap": [-216.28, -206.07, -195.86, -185.65, -175.44, -165.23, -155.01, -144.80, -134.59, -124.38, 
                   -114.17, -103.96, -93.75, -83.54, -73.33, -63.12, -52.91, -42.70, -32.49, -22.28, 
                   -12.07, -1.86, 8.35, 18.56, 28.77],
    "<dGg>": [-3.11, -3.06, -3.19, -3.37, -3.43, -3.30, -2.96, -2.24, -1.24, 0.10, 
              1.62, 3.64, 5.56, 7.43, 9.47, 11.51, 13.63, 15.58, 17.25, 18.13, 
              18.16, 17.31, 15.42, 12.49, 8.82],
    "<dGg norm>": [30.07, 30.12, 29.99, 29.81, 29.75, 29.88, 30.22, 30.94, 31.94, 33.28, 
                   34.80, 36.82, 38.74, 40.61, 42.65, 44.69, 46.81, 48.76, 50.43, 51.31, 
                   51.34, 50.49, 48.60, 45.67, 41.99],
    "pts": [109, 452, 807, 1374, 2024, 2486, 2821, 3437, 3382, 3262, 
            1784, 1255, 1870, 2408, 3033, 2516, 640, 135, 49, 148, 
            277, 654, 902, 1142, 1361],
    "<c1**2>": [0.987, 0.986, 0.984, 0.983, 0.981, 0.979, 0.976, 0.973, 0.969, 0.964, 
                0.959, 0.950, 0.941, 0.928, 0.912, 0.893, 0.867, 0.828, 0.782, 0.697, 
                0.611, 0.514, 0.417, 0.325, 0.249],
    "<c2**2>": [0.013, 0.014, 0.016, 0.017, 0.019, 0.021, 0.024, 0.027, 0.031, 0.036, 
                0.041, 0.050, 0.059, 0.072, 0.088, 0.107, 0.133, 0.172, 0.218, 0.303, 
                0.389, 0.486, 0.583, 0.675, 0.751],
    "<r_xy>": [4.104, 4.141, 4.083, 3.995, 4.028, 3.992, 3.968, 3.909, 3.864, 3.773, 
               3.718, 3.693, 3.687, 3.669, 3.693, 3.707, 3.700, 3.532, 3.418, 3.354, 
               3.352, 3.361, 3.349, 3.353, 3.368]
}

df = pd.DataFrame(data)

# Step 2: Create the violin plot
plt.figure(figsize=(12, 8))
sns.violinplot(data=df, y="<dGg>")
plt.title('Violin Plot of <dGg> for First 25 Bins')
plt.xlabel('Data Points')
plt.ylabel('<dGg>')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data
data_full = {
    "bin": range(1, 51),
    "energy_gap": [-216.28, -206.07, -195.86, -185.65, -175.44, -165.23, -155.01, -144.80, -134.59, -124.38, 
                   -114.17, -103.96, -93.75, -83.54, -73.33, -63.12, -52.91, -42.70, -32.49, -22.28, 
                   -12.07, -1.86, 8.35, 18.56, 28.77, 38.98, 49.19, 59.40, 69.61, 79.82, 90.03, 100.24, 
                   110.45, 120.66, 130.87, 141.08, 151.29, 161.50, 171.71, 181.92, 192.13, 202.34, 212.55, 
    "energy_gap": [-213.81, -204.37, -194.93, -185.49, -176.05, -166.61, -157.17, -147.73, -138.29, -128.85, 
                   -119.41, -109.97, -100.53, -91.09, -81.65, -72.21, -62.77, -53.33, -43.89, -34.45, 
                   -25.01, -15.57, -6.13, 3.31, 12.75],
    "<dGg>": [-3.12, -3.41, -3.50, -3.55, -3.42, -3.03, -2.38, -1.45, -0.44, 0.82, 
              2.13, 3.51, 5.20, 6.73, 8.30, 10.18, 12.30, 14.59, 16.98, 19.42, 
              21.51, 23.34, 23.98, 23.85, 22.39],
    "<dGg norm>": [25.95, 25.66, 25.57, 25.52, 25.65, 26.05, 26.69, 27.62, 28.63, 29.89, 
                   31.20, 32.58, 34.27, 35.81, 37.37, 39.25, 41.37, 43.66, 46.05, 48.50, 
                   50.59, 52.41, 53.05, 52.92, 51.46],
    "pts": [55, 398, 984, 2420, 3106, 2995, 2342, 2190, 1684, 1554, 
            1515, 1306, 1625, 3040, 3141, 3319, 4289, 4304, 2634, 1326, 
            414, 83, 51, 39, 21],
    "<c1**2>": [0.987, 0.985, 0.984, 0.983, 0.981, 0.979, 0.976, 0.974, 0.970, 0.966, 
                0.961, 0.955, 0.947, 0.938, 0.927, 0.910, 0.891, 0.865, 0.831, 0.788, 
                0.732, 0.647, 0.567, 0.484, 0.373],
    "<c2**2>": [0.013, 0.015, 0.016, 0.017, 0.019, 0.021, 0.024, 0.026, 0.030, 0.034, 
                0.039, 0.045, 0.053, 0.062, 0.073, 0.090, 0.109, 0.135, 0.169, 0.212, 
                0.268, 0.353, 0.433, 0.516, 0.627],
    "<r_xy>": [4.047, 4.122, 4.075, 4.115, 4.121, 4.140, 4.085, 4.024, 3.991, 3.871, 
               3.794, 3.759, 3.768, 3.776, 3.750, 3.704, 3.687, 3.656, 3.639, 3.650, 
               3.618, 3.582, 3.547, 3.471, 3.461]
}


# Add a new column to distinguish between the two metrics
df_full_melted = df_full.melt(id_vars=['bin', 'dataset'], value_vars=['<dGg>', '<dGg norm>'], var_name='metric', value_name='value')
df_25_melted = df_25.melt(id_vars=['bin', 'dataset'], value_vars=['<dGg>', '<dGg norm>'], var_name='metric', value_name='value')

# Combine the melted DataFrames
df_combined_melted = pd.concat([df_full_melted, df_25_melted], ignore_index=True)

# Plot
plt.figure(figsize=(14, 8))
sns.violinplot(x='dataset', y='value', hue='metric', data=df_combined_melted, split=True)
plt.title('Violin Plot of <dGg> and <dGg norm>')
plt.xlabel('Dataset')
plt.ylabel('Value')
plt.grid(True)
plt.legend(title='Metric')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data for the full dataset
data_full = {
    "bin": range(1, 51),
    "energy_gap": [-216.28, -206.07, -195.86, -185.65, -175.44, -165.23, -155.01, -144.80, -134.59, -124.38, 
                   -114.17, -103.96, -93.75, -83.54, -73.33, -63.12, -52.91, -42.70, -32.49, -22.28, 
                   -12.07, -1.86, 8.35, 18.56, 28.77, 38.98, 49.19, 59.40, 69.61, 79.82, 90.03, 100.24, 
                   110.45, 120.66, 130.87, 141.08, 151.29, 161.50, 171.71, 181.92, 192.13, 202.34, 212.55, 
                   222.76, 232.97, 243.18, 253.39, 263.60, 273.81, 284.02],
    "<dGg>": [-3.11, -3.06, -3.19, -3.37, -3.43, -3.30, -2.96, -2.24, -1.24, 0.10, 
              1.62, 3.64, 5.56, 7.43, 9.47, 11.51, 13.63, 15.58, 17.25, 18.13, 
              18.16, 17.31, 15.42, 12.49, 8.82, 4.89, 0.29, -4.03, -8.49, -12.62, 
              -16.54, -19.96, -23.29, -26.18, -28.56, -30.38, -31.67, -32.46, -32.95, 
              -33.09, -33.06, -33.12, -33.18, -33.16, -33.09, -32.99, -32.84, -32.74, 
              -32.66, -32.59],
}

# Define the data for the 25 points
data_25 = {
    "bin": range(1, 26),
    "energy_gap": [-213.81, -204.37, -194.93, -185.49, -176.05, -166.61, -157.17, -147.73, -138.29, -128.85, 
                   -119.41, -109.97, -100.53, -91.09, -81.65, -72.21, -62.77, -53.33, -43.89, -34.45, 
                   -25.01, -15.57, -6.13, 3.31, 12.75],
    "<dGg>": [-3.12, -3.41, -3.50, -3.55, -3.42, -3.03, -2.38, -1.45, -0.44, 0.82, 
              2.13, 3.51, 5.20, 6.73, 8.30, 10.18, 12.30, 14.59, 16.98, 19.42, 
              21.51, 23.34, 23.98, 23.85, 22.39]
}

# Convert the data to DataFrames
df_full = pd.DataFrame(data_full)
df_25 = pd.DataFrame(data_25)

# Add a column to identify the dataset
df_full['dataset'] = 'Full'
df_25['dataset'] = '25 Points'

# Melt the DataFrames for plotting
df_full_melted = df_full.melt(id_vars=['dataset'], value_vars=['<dGg>'], var_name='metric', value_name='value')
df_25_melted = df_25.melt(id_vars=['dataset'], value_vars=['<dGg>'], var_name='metric', value_name='value')

# Combine the melted DataFrames
df_combined_melted = pd.concat([df_full_melted, df_25_melted], ignore_index=True)

# Plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='dataset', y='value', data=df_combined_melted, inner="quartile", palette="muted")
plt.title('Violin Plot of <dGg> for Full Dataset and 25 Points')
plt.xlabel('Dataset')
plt.ylabel('<dGg>')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_92981/1005437588.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='dataset', y='value', data=df_combined_melted, inner="quartile", palette="muted")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data
data_full = {
    "bin": range(1, 51),
    "energy_gap": [-216.28, -206.07, -195.86, -185.65, -175.44, -165.23, -155.01, -144.80, -134.59, -124.38, 
                   -114.17, -103.96, -93.75, -83.54, -73.33, -63.12, -52.91, -42.70, -32.49, -22.28, 
                   -12.07, -1.86, 8.35, 18.56, 28.77, 38.98, 49.19, 59.40, 69.61, 79.82, 90.03, 100.24, 
                   110.45, 120.66, 130.87, 141.08, 151.29, 161.50, 171.71, 181.92, 192.13, 202.34, 212.55, 
                   222.76, 232.97, 243.18, 253.39, 263.60, 273.81, 284.02],
    "<dGg>": [-3.11, -3.06, -3.19, -3.37, -3.43, -3.30, -2.96, -2.24, -1.24, 0.10, 
              1.62, 3.64, 5.56, 7.43, 9.47, 11.51, 13.63, 15.58, 17.25, 18.13, 
              18.16, 17.31, 15.42, 12.49, 8.82, 4.89, 0.29, -4.03, -8.49, -12.62, 
              -16.54, -19.96, -23.29, -26.18, -28.56, -30.38, -31.67, -32.46, -32.95, 
              -33.09, -33.06, -33.12, -33.18, -33.16, -33.09, -32.99, -32.84, -32.74, 
              -32.66, -32.59],
}

data_25 = {
    "bin": range(1, 26),
    "energy_gap": [-213.81, -204.37, -194.93, -185.49, -176.05, -166.61, -157.17, -147.73, -138.29, -128.85, 
                   -119.41, -109.97, -100.53, -91.09, -81.65, -72.21, -62.77, -53.33, -43.89, -34.45, 
                   -25.01, -15.57, -6.13, 3.31, 12.75],
    "<dGg>": [-3.12, -3.41, -3.50, -3.55, -3.42, -3.03, -2.38, -1.45, -0.44, 0.82, 
              2.13, 3.51, 5.20, 6.73, 8.30, 10.18, 12.30, 14.59, 16.98, 19.42, 
              21.51, 23.34, 23.98, 23.85, 22.39],
}

# Add a new column to distinguish between the two metrics
df_full_melted = df_full.melt(id_vars=['bin', 'dataset'], value_vars=['<dGg>', '<dGg norm>'], var_name='metric', value_name='value')
df_25_melted = df_25.melt(id_vars=['bin', 'dataset'], value_vars=['<dGg>', '<dGg norm>'], var_name='metric', value_name='value')

# Combine the melted DataFrames
df_combined_melted = pd.concat([df_full_melted, df_25_melted], ignore_index=True)


# Convert to DataFrames
df_full = pd.DataFrame(data_full)
df_25 = pd.DataFrame(data_25)

# Add a column to identify the dataset
df_full['dataset'] = 'Full Dataset'
df_25['dataset'] = '25 Points'

# Melt both DataFrames for <dGg> only
df_full_melted = df_full.melt(id_vars=['dataset'], value_vars=['<dGg>'], var_name='metric', value_name='value')
df_25_melted = df_25.melt(id_vars=['dataset'], value_vars=['<dGg>'], var_name='metric', value_name='value')

# Combine the melted DataFrames
df_combined_melted = pd.concat([df_full_melted, df_25_melted], ignore_index=True)

# Plot
plt.figure(figsize=(14, 8))
sns.violinplot(x='dataset', y='value', data=df_combined_melted, palette="muted")
plt.title('Violin Plot of <dGg> for Full Dataset and 25 Points')
plt.xlabel('Dataset')
plt.ylabel('<dGg> Value')
plt.grid(True)
plt.show()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/hp/anaconda3/envs/openMM/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_92981/2881267584.py", line 32, in <module>
#     df_full_melted = df_full.melt(id_vars=['bin', 'dataset'], value_vars=['<dGg>', '<dGg norm>'], var_name='metric', value_name='value')
#   File "/home/hp/anaconda3/envs/openMM/lib/python3.8/site-packages/pandas/core/frame.py", line 8975, in melt
#     return melt(
#   File "/home/hp/anaconda3/envs/openMM/lib/python3.8/site-packages/pandas/core/reshape/melt.py", line 92, in melt
#     raise KeyError(
# KeyError: "The following 'value_vars' are not present in the DataFrame: ['<dGg norm>']"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Define the data
data = {
    "bin": list(range(1, 51)),
    "<dGg>": [
        -39.65, -37.03, -36.99, -32.49, -32.52, -33.70, -33.41, -32.52, -32.77, -31.22,
        -28.58, -24.70, -24.93, -26.88, -25.23, -22.87, -19.81, -17.86, -17.77, -16.06,
        -14.61, -12.60, -10.90, -9.17, -8.41, -9.46, -11.80, -14.94, -18.60, -23.74,
        -27.94, -33.04, -37.00, -41.33, -44.07, -45.34, -46.08, -46.60, -46.91, -46.96,
        -48.48, -50.51, -52.34, -52.52, -50.87, -48.60, -50.26, -49.73, -47.77, -49.62
    ]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Generate synthetic data for violin plot
synthetic_data = []

for bin_num, dGg_value in zip(df["bin"], df["<dGg>"]):
    # Generate 100 data points around the mean value with a small random noise
    synthetic_values = np.random.normal(dGg_value, 2, 100)
    bin_column = [bin_num] * 100
    synthetic_data.extend(list(zip(bin_column, synthetic_values)))

# Create a new DataFrame for synthetic data
df_synthetic = pd.DataFrame(synthetic_data, columns=["bin", "<dGg>"])

# Create the violin plot
plt.figure(figsize=(12, 8))
sns.violinplot(x="bin", y="<dGg>", data=df_synthetic)
plt.title('Violin Plot of <dGg> Across Bins')
plt.xlabel('Bin')
plt.ylabel('<dGg>')
plt.xticks(rotation=90)  # Rotate x labels if needed
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data
data = {
    "bin": list(range(1, 51)),
    "energy_gap": [
        -248.52, -237.66, -226.80, -215.94, -205.07, -194.21, -183.35, -172.49, -161.63, -150.77,
        -139.90, -129.04, -118.18, -107.32, -96.46, -85.60, -74.74, -63.87, -53.01, -42.15,
        -31.29, -20.43, -9.57, 1.30, 12.16, 23.02, 33.88, 44.74, 55.60, 66.47, 77.33, 88.19,
        99.05, 109.91, 120.77, 131.64, 142.50, 153.36, 164.22, 175.08, 185.94, 196.80, 207.67,
        218.53, 229.39, 240.25, 251.11, 261.97, 272.84, 283.70
    ],
    "<dGg>": [
        -39.65, -37.03, -36.99, -32.49, -32.52, -33.70, -33.41, -32.52, -32.77, -31.22,
        -28.58, -24.70, -24.93, -26.88, -25.23, -22.87, -19.81, -17.86, -17.77, -16.06,
        -14.61, -12.60, -10.90, -9.17, -8.41, -9.46, -11.80, -14.94, -18.60, -23.74,
        -27.94, -33.04, -37.00, -41.33, -44.07, -45.34, -46.08, -46.60, -46.91, -46.96,
        -48.48, -50.51, -52.34, -52.52, -50.87, -48.60, -50.26, -49.73, -47.77, -49.62
    ]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Create the violin plot for <dGg> values
plt.figure(figsize=(10, 6))
sns.violinplot(y=df["<dGg>"], inner='quartile', scale='width')
#plt.title('Violin Plot of <dGg> Values')
plt.ylabel('<dGg>')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_92981/1245400790.py:29: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(y=df["<dGg>"], inner='quartile', scale='width')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data
data = {
    "bin": list(range(1, 51)),
    "energy_gap": [
        -248.52, -237.66, -226.80, -215.94, -205.07, -194.21, -183.35, -172.49, -161.63, -150.77,
        -139.90, -129.04, -118.18, -107.32, -96.46, -85.60, -74.74, -63.87, -53.01, -42.15,
        -31.29, -20.43, -9.57, 1.30, 12.16, 23.02, 33.88, 44.74, 55.60, 66.47, 77.33, 88.19,
        99.05, 109.91, 120.77, 131.64, 142.50, 153.36, 164.22, 175.08, 185.94, 196.80, 207.67,
        218.53, 229.39, 240.25, 251.11, 261.97, 272.84, 283.70
    ],
    "<dGg>": [
        -39.65, -37.03, -36.99, -32.49, -32.52, -33.70, -33.41, -32.52, -32.77, -31.22,
        -28.58, -24.70, -24.93, -26.88, -25.23, -22.87, -19.81, -17.86, -17.77, -16.06,
        -14.61, -12.60, -10.90, -9.17, -8.41, -9.46, -11.80, -14.94, -18.60, -23.74,
        -27.94, -33.04, -37.00, -41.33, -44.07, -45.34, -46.08, -46.60, -46.91, -46.96,
        -48.48, -50.51, -52.34, -52.52, -50.87, -48.60, -50.26, -49.73, -47.77, -49.62
    ],
    "<dGg norm>": [
        12.87, 15.49, 15.53, 20.03, 20.00, 18.82, 19.11, 20.01, 19.75, 21.30,
        23.94, 27.82, 27.60, 25.64, 27.29, 29.65, 32.72, 34.66, 34.75, 36.47,
        37.92, 39.92, 41.62, 43.35, 44.11, 43.06, 40.73, 37.58, 33.92, 28.78,
        24.58, 19.48, 15.52, 11.19, 8.45, 7.18, 6.44, 5.92, 5.61, 5.56,
        4.04, 2.01, 0.18, 0.00, 1.65, 3.92, 2.26, 2.79, 4.75, 2.90
    ]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Create the violin plot for <dGg norm> values
plt.figure(figsize=(8, 6))
sns.violinplot(y=df["<dGg norm>"], inner='quartile', scale='width')
plt.title('Violin Plot of <dGg norm> Values')
plt.xlabel('Distribution')
plt.ylabel('<dGg norm>')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_92981/1179602112.py:36: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(y=df["<dGg norm>"], inner='quartile', scale='width')
