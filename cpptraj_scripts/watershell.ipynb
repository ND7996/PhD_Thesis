# %%
import matplotlib.pyplot as plt
import pandas as pd

# Step 1: Read the data from the .dat file
file_path = '/home/nayanika/Work/Thesis/Analysis_Scripts/Files/watershellmousesec.dat'

# Initialize empty lists to store x and y data
x_data = []
y_data = []

data = pd.read_csv(file_path, delim_whitespace=True)
x_data = data.iloc[:, 0]
y_data = data.iloc[:, 1]

# Step 2: Create a subplot with 1 row and 2 columns
fig = plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(x_data, y_data, label='Data')
plt.xlabel(r'Frame')
plt.ylabel(r'')
plt.title(r'Number of solvent molecules in first solvent shell.')
plt.legend()
plt.grid(True)

x_data = []
y_data = []

data = pd.read_csv(file_path, delim_whitespace=True)
x_data = data.iloc[:, 0]
y_data = data.iloc[:, 2]

# Step 3: Create another subplot for the second plot
plt.subplot(1, 2, 2)
# Assuming you have another set of data for the second plot, replace the following line with your actual data
plt.plot(x_data, y_data, label='Data')
plt.xlabel(r'Frame')
plt.ylabel(r'Count the number of waters')
plt.title(r'Number of solvent molecules in second solvent shell.')
plt.legend()
plt.grid(True)

# Step 4: Adjust layout to prevent overlapping titles
plt.tight_layout()
plt.show()
