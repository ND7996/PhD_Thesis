# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
y = np.array([5, 5, 5])
mylabels = ["Struture-Function Relationship", "REACT", "INTERACT"]
myexplode = [0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.title("Parts Of Thesis")
plt.show()
